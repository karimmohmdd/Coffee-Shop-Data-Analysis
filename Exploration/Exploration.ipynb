# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('coffee_uncleaned.csv')
df
# Out:
#       hour_of_day cash_type  money          coffee_name Time_of_Day Weekday  \
# 0             NaN      card  23.02            Americano     Morning     NaN
# 1            11.0       NaN    NaN  Americano with Mili     Morning     Mon
# 2            10.0      card  21.06             Espresso         NaN     Tue
# 3            14.0      card  35.76                Cocoe   Afternoon     Sun
# 4            20.0      card  35.76        Hot Chocolate       Night     Thu
# ...           ...       ...    ...                  ...         ...     ...
# 3897        -11.0      card  23.02                  NaN     Morning     Sat
# 3898         10.0      card    NaN                  NaN     Morning     Mon
# 3899         11.0      card  27.92  Americano with Milk     Morning     Tue
# 3900         19.0       NaN  35.76           Cappuccino       Night     Thu
# 3901          8.0      card    NaN                  NaN         NaN     Wed
#
#      Month_name  Weekdaysort  Monthsort        Date     Time
# 0           Jul          NaN        7.0  25/07/2024  26:04.7
# 1           Feb          NaN        2.0  17/02/2025  53:58.6
# 2           Oct        140.0       10.0  22/10/2024  51:32.3
# 3           NaN          7.0        3.0  23/03/2025      NaN
# 4           Oct          4.0      -10.0         NaN  14:04.8
# ...         ...          ...        ...         ...      ...
# 3897        Aug          NaN        NaN  10/08/2024  52:33.8
# 3898        Aug          1.0        NaN  26/08/2024  37:44.5
# 3899        NaN          2.0        0.0  09/07/2024      NaN
# 3900        Mar          4.0        3.0  20/03/2025  57:48.5
# 3901        Feb          3.0        2.0  26/02/2025  57:37.2
#
# [3902 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3902 entries, 0 to 3901
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  3326 non-null   float64
#  1   cash_type    3317 non-null   object
#  2   money        3337 non-null   float64
#  3   coffee_name  3317 non-null   object
#  4   Time_of_Day  3317 non-null   object
#  5   Weekday      3317 non-null   object
#  6   Month_name   3317 non-null   object
#  7   Weekdaysort  3334 non-null   float64
#  8   Monthsort    3329 non-null   float64
#  9   Date         3317 non-null   object
#  10  Time         3317 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 335.5+ KB

# %%
df.isna().sum()
# Out:
# hour_of_day    576
# cash_type      585
# money          565
# coffee_name    585
# Time_of_Day    585
# Weekday        585
# Month_name     585
# Weekdaysort    568
# Monthsort      573
# Date           585
# Time           585
# dtype: int64

# %%
df.describe()
# Out:
#        hour_of_day        money  Weekdaysort    Monthsort
# count  3326.000000  3337.000000  3334.000000  3329.000000
# mean     29.891461   151.305394    14.756749    13.651847
# std      83.611964   578.409024    65.559279    46.851159
# min    -513.000000 -3039.600000  -490.000000  -348.000000
# 25%      10.000000    27.920000     2.000000     3.000000
# 50%      14.000000    32.820000     4.000000     6.000000
# 75%      18.000000    35.760000     6.000000    10.000000
# max     594.000000  3289.500000   490.000000   348.000000

# %%
df.describe(include=['object'])
# Out:
#        cash_type          coffee_name Time_of_Day Weekday Month_name  \
# count       3317                 3317        3317    3317       3317
# unique         5                   33          15       7         12
# top         card  Americano with Milk   Afternoon     Tue        Mar
# freq        3144                  722        1064     543        444
#
#               Date     Time
# count         3317     3317
# unique         535     2971
# top     11/10/2024  55:31.4
# freq            25        4

# %%
df.nunique()
# Out:
# hour_of_day      56
# cash_type         5
# money            42
# coffee_name      33
# Time_of_Day      15
# Weekday           7
# Month_name       12
# Weekdaysort      26
# Monthsort        45
# Date            535
# Time           2971
# dtype: int64

# %%
df.shape
# Out:
# (3902, 11)

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df.drop_duplicates()
# Out:
#       hour_of_day cash_type  money          coffee_name Time_of_Day Weekday  \
# 0             NaN      card  23.02            Americano     Morning     NaN
# 1            11.0       NaN    NaN  Americano with Mili     Morning     Mon
# 2            10.0      card  21.06             Espresso         NaN     Tue
# 3            14.0      card  35.76                Cocoe   Afternoon     Sun
# 4            20.0      card  35.76        Hot Chocolate       Night     Thu
# ...           ...       ...    ...                  ...         ...     ...
# 3897        -11.0      card  23.02                  NaN     Morning     Sat
# 3898         10.0      card    NaN                  NaN     Morning     Mon
# 3899         11.0      card  27.92  Americano with Milk     Morning     Tue
# 3900         19.0       NaN  35.76           Cappuccino       Night     Thu
# 3901          8.0      card    NaN                  NaN         NaN     Wed
#
#      Month_name  Weekdaysort  Monthsort        Date     Time
# 0           Jul          NaN        7.0  25/07/2024  26:04.7
# 1           Feb          NaN        2.0  17/02/2025  53:58.6
# 2           Oct        140.0       10.0  22/10/2024  51:32.3
# 3           NaN          7.0        3.0  23/03/2025      NaN
# 4           Oct          4.0      -10.0         NaN  14:04.8
# ...         ...          ...        ...         ...      ...
# 3897        Aug          NaN        NaN  10/08/2024  52:33.8
# 3898        Aug          1.0        NaN  26/08/2024  37:44.5
# 3899        NaN          2.0        0.0  09/07/2024      NaN
# 3900        Mar          4.0        3.0  20/03/2025  57:48.5
# 3901        Feb          3.0        2.0  26/02/2025  57:37.2
#
# [3895 rows x 11 columns]

# %%
df['coffee_name'].value_counts()
# Out:
# coffee_name
# Americano with Milk    722
# Latte                  671
# Americano              528
# Cappuccino             433
# Cortado                251
# Hot Chocolate          246
# Cocoa                  221
# Espresso               114
# Latta                   11
# Latti                   10
# Americani               10
# Americano with Mili     10
# Americano with Mile      9
# Americana                9
# Americane                8
# Americano with Milo      8
# Cortade                  7
# Latto                    7
# Cappuccina               7
# Americano with Mila      5
# Cappuccine               4
# Hot Chocolata            4
# Cappuccini               4
# Hot Chocolato            3
# Cocoe                    3
# Cortada                  3
# Cortadi                  3
# Hot Chocolati            1
# Espressi                 1
# Cocoo                    1
# Cocoi                    1
# Espressa                 1
# Espresse                 1
# Name: count, dtype: int64

# %%
df['Time_of_Day'].value_counts()
# Out:
# Time_of_Day
# Afternoon    1064
# Morning      1045
# Night        1038
# Afternooo      22
# Mornino        19
# Nigha          15
# Afternooa      15
# Mornine        14
# Afternooi      14
# Nigho          13
# Mornini        13
# Nighe          13
# Nighi          12
# Mornina        10
# Afternooe      10
# Name: count, dtype: int64

# %%
df['money'].hist()
# Out:
# <Axes: >
